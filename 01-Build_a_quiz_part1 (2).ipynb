# %% [markdown]
# # Build a quizz
#
# ---

# %% [markdown]
# Let's tackle our first project together. Find a partner and start coding a quiz together! Your program should:
#
# 1. Ask a question to a user via the console
# 2. Verify whether the answer is correct or not
# 3. If the answer is correct, you should print out: `Good job! This is the right answer`
#
# * Else, it should print out : `Too bad! that is not the correct answer`
#
# 4. Ask three questions following this model.

# %%
print("Here you have our quiz !")

answer1 = input("What's your age?")
if answer1 != "31":
    print("Too bad! That is not the correct answer")
else:
    print("Good job! This is the right answer")

answer2 = input("Waht's your birth date?")
if answer2 != "1990":
    print("Too bad! That is not the correct answer")
else:
    print("Good job! This is the right answer")

answer3 = input("What's the name of your heroe?")
if answer3 != "Elon Musk":
    print("Too bad! That is not the correct answer")
else:
    print("Good job! This is the right answer")

# %% [markdown]
# There's a problem with our quizz : if the user has not given the right answer, the program goes to next question. We would rather like to ask again the same question if the answer was wrong.
#
# 5. Using a `while` loop, make sure that the same question will be asked again when the answer was wrong
#
# 6. Rewrite your code such that this behaviour is applied to all questions.

# %%
print("Here you have our quiz !")

#definition of variables
question_1 = "What's your age?"
question_2 = "What's your birth date?"
question_3 = "What's the name of your heroe?"

#ask the first question and keep looping until the answer is correct
print(question_1)
attempt = 1

while True:
    answer1 = input("Answer:")
    if answer1 != "31":
        print("Too bad! That is not the correct answer")
        attempt += 1
        continue
    elif answer1 == "31":
        print("Good job! This is the right answer")
        break

#ask the second question and keep looping until the answer is correct
print(question_2)
attempt = 1

while True:
    answer2 = input("Answer:")
    if answer2 != "1990":
        print("Too bad! That is not the correct answer")
        attempt += 1
        continue
    elif answer2 == "1990":
        print("Good job! This is the right answer")
        break
        
#ask the thrid question and keep looping until the answer is correct
print(question_3)
attempt = 1

while True:
    answer3 = input("Answer:")
    if answer3 != "Elon Musk":
        print("Too bad! That is not the correct answer")
        attempt += 1
        continue
    elif answer3 == "Elon Musk":
        print("Good job! This is the right answer")
        break

# %% [markdown]
# Now, we would like to tackle a last problem : we want to allow only 3 wrong answers (among all questions).
#
# 7. Improve your code : if the user makes 3 wrong answers, the program should stop and print ("Too bad, you lost the game !")

# %%
print("Here you have our quiz ! You have three lives.")

#definition of variables
question_1 = "What's your age?"
question_2 = "What's your birth date?"
question_3 = "What's the name of your heroe?"

#ask the first question and keep looping until the answer is correct
print(question_1)
attempt = 0

while True:
    answer1 = input("Answer:")
    if answer1 != "31":
        print("Too bad! That is not the correct answer")
        attempt += 1
        if attempt ==3:
            print("Too bad, you lost the game !")
            break
        else:
            continue
    elif answer1 == "31":
        print("Good job! This is the right answer")
        break

#ask the second question and keep looping until the answer is correct

while True:
    if attempt ==3:
        break
    print(question_2)
    answer2 = input("Answer:")
    if answer2 != "1990":
        print("Too bad! That is not the correct answer")
        attempt += 1
        if attempt ==3:
            print("Too bad, you lost the game !")
            break
        else:
            continue
    elif answer2 == "1990":
        print("Good job! This is the right answer")
        break
        
#ask the thrid question and keep looping until the answer is correct

while True:
    if attempt ==3:
        break
    print(question_3)
    answer3 = input("Answer:")
    if answer3 != "Elon Musk":
        print("Too bad! That is not the correct answer")
        attempt += 1
        if attempt ==3:
            print("Too bad, you lost the game !")
            break
        else:
            continue
    elif answer3 == "Elon Musk":
        print("Good job! This is the right answer")
        break
